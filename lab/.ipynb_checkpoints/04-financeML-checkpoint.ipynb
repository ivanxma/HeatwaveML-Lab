# %%
# %load_ext sql

# %%
mypass = "mysql+mysqlconnector://user:x@1.1.1.1/financedb"
# %sql  $mypass

# %%
# %%sql
# show databases;
# use ML_SCHEMA_admin;
# select * from MODEL_CATALOG;
# Out:
#  * mysql+mysqlconnector://admin:***@143.47.226.231/financedb
#    mysql+mysqlconnector://admin:***@143.47.226.231/irisdb
# 34 rows affected.
# 0 rows affected.
# 5 rows affected.
# [(2, 'iris_model', 'ExtraTreesClassifier', 'classification', None, 'admin', 1762855194, 'class', 'irisdb.iris_train', '["sepal length", "sepal width", "petal length", "petal width"]', '{"permutation_importance": {"petal width": 0.2301, "sepal width": 0.0056, "petal length": 0.2192, "sepal length": 0.0056}}', None, 404185, None, '{"task": "classification", "notes": null, "chunks": 1, "format": "HWMLv2.0", "n_rows": 120, "status": "Ready", "options": {"task": "classification",  ... (1102 characters truncated) ... elected_column_names": ["petal length", "petal width", "sepal length", "sepal width"], "training_drift_metric": {"mean": 0.2779, "variance": 0.1398}}'),
#  (12, 'anomaly_detection_semi_supervised_use_case', 'GKNN', 'anomaly_detection', None, 'admin', 1762879316, 'target', 'CreditCardAnomalyDB.credit_card_train', '["transaction_id", "home_address", "purchase_location", "purchase_amount", "purchase_time"]', '{}', None, 22790, None, '{"task": "anomaly_detection", "notes": null, "chunks": 1, "format": "HWMLv2.0", "n_rows": 31, "status": "Ready", "options": {"task": "anomaly_detecti ... (1333 characters truncated) ...  null, "selected_column_names": ["purchase_amount", "purchase_time", "transaction_id"], "training_drift_metric": {"mean": 0.177, "variance": 0.0231}}'),
#  (13, 'LogAnomalyDB.training_data_admin_1762879752602', 'GKNN', 'log_anomaly_detection', None, 'admin', 1762879766, None, 'LogAnomalyDB.training_data', '["log_message"]', '{}', None, 75880, None, '{"task": "log_anomaly_detection", "notes": null, "chunks": 1, "format": "HWMLv2.0", "n_rows": 12, "status": "Ready", "options": {"task": "log_anomaly ... (1513 characters truncated) ... ization_metric": null, "selected_column_names": ["parsed_log_segment", "raw_log_segment"], "training_drift_metric": {"mean": null, "variance": null}}'),
#  (14, 'LogAnomalyDB.training_data_admin_1762880121183', 'GKNN', 'anomaly_detection', None, 'admin', 1762880126, 'target', 'LogAnomalyDB.training_data', '["log_message"]', '{}', None, 14186, None, '{"task": "anomaly_detection", "notes": null, "chunks": 1, "format": "HWMLv2.0", "n_rows": 12, "status": "Ready", "options": {"task": "anomaly_detecti ... (1268 characters truncated) ... ame": "target", "optimization_metric": null, "selected_column_names": ["log_message"], "training_drift_metric": {"mean": 0.2292, "variance": 0.0299}}'),
#  (15, 'topic_modeling_use_case', 'NoneType', 'topic_modeling', None, 'admin', 1764681169, None, 'topic_modeling_data.movies', '["description"]', '{}', None, 11533, None, '{"task": "topic_modeling", "notes": null, "chunks": 1, "format": "HWMLv2.0", "n_rows": 21, "status": "Ready", "options": {"task": "topic_modeling", " ... (595 characters truncated) ... l, "target_column_name": null, "optimization_metric": null, "selected_column_names": null, "training_drift_metric": {"mean": null, "variance": null}}')]

# %%
# %%sql
# create database if not exists financedb;
# show tables from financedb;
# Out:
#  * mysql+mysqlconnector://admin:***@143.47.226.231/financedb
#    mysql+mysqlconnector://admin:***@143.47.226.231/irisdb
# 1 rows affected.
# 0 rows affected.
# []

# %%
# %%sql
# SET @db_list = '["financedb"]';
# SET @ext_tables = ('[{'
#  '"db_name": "financedb",'
#  '"tables": [{'
#           '"table_name": "fin2",'
#           '"dialect": {'
#               '"format": "csv",'
#               '"has_header": true,'
#               '"date_format": "auto",'
#               '"time_format": "auto",'
#               '"trim_spaces": true,'
#               '"field_delimiter": ",",'
#               '"record_delimiter": "\\n"'
#           '},'
#           '"file": [{'
#               '"par": "https://objectstorage.us-ashburn-1.oraclecloud.com/p/KVVfUi0hD4Jur4Sgq5KolACa7lQz57tgXqct2GypF7IYrUUeJw51rtxt11qt08yZ/n/idazzjlcjqzj/b/HWdatalake/o/mycsv-folder/Synthetic_Financial_datasets_log.csv"'
#         '}]'
#     '}] }]');
# SET @options = JSON_OBJECT('mode', 'normal', 'external_tables', CAST(@ext_tables AS JSON));
# select @options;
# Out:
#  * mysql+mysqlconnector://admin:***@143.47.226.231/financedb
#    mysql+mysqlconnector://admin:***@143.47.226.231/irisdb
# 0 rows affected.
# 0 rows affected.
# 0 rows affected.
# 1 rows affected.
# [('{"mode": "normal", "external_tables": [{"tables": [{"file": [{"par": "https://objectstorage.us-ashburn-1.oraclecloud.com/p/KVVfUi0hD4Jur4Sgq5KolACa7l ... (191 characters truncated) ... o", "time_format": "auto", "trim_spaces": true, "field_delimiter": ",", "record_delimiter": "\\n"}, "table_name": "fin2"}], "db_name": "financedb"}]}',)]

# %%
# %%sql
# call sys.heatwave_load(@db_list,@options);
# Out:
#  * mysql+mysqlconnector://admin:***@143.47.226.231/financedb
#    mysql+mysqlconnector://admin:***@143.47.226.231/irisdb

# %%
# %%time
# %%sql
use financedb;
select isFraud, count(*) from fin2 group by isFraud;

# %%
# %%sql
# describe finance;

# %%
# %%time
# %%sql
set @@autocommit=1;
set @anomaly = 'anomaly-model02';
CALL sys.ML_TRAIN('financedb.fin2', NULL, JSON_OBJECT('task', 'anomaly_detection'), @anomaly);

# %%
# %%time
# %%sql
CALL sys.ML_TRAIN('financedb.finance', "isFraud", 
CAST('{"task": "anomaly_detection", "experimental": {"semisupervised": {}}}' as JSON), @semisupervised_model);
